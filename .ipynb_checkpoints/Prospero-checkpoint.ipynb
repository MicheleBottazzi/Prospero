# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
os.getcwd()
# Out:
# '/home/drugo/eclipse-workspace/Prospero'

# %%
dfT= pd.read_csv('resources/Input/dataET_point/Viote/Viote_Temp.csv',parse_dates=[1],sep=',',
                 skiprows=6,low_memory=False, na_values=-9999)
dfT = dfT.iloc[:,1:]
dfT.columns = ['Datetime','Tair']
dfT.head(10)
dfT.Tair = dfT.Tair+273
dfT.Tair.plot()

# %%
dfT1= pd.read_csv('resources/Output/LeafTemperatureSun.csv',parse_dates=[1],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfT1 = dfT1.iloc[:,1:]
dfT1.columns = ['Datetime','Tsun']
dfT1.head(10)
# dfT1[dfT1.Tsun==288]=np.nan

dfT1.Tsun.plot()

# %%
dfT1.loc[dfT1.Tsun>500]
# Out:
#                   Datetime        Tsun
# 84083  2017-10-18 17:30:00  540.290570
# 101603 2018-10-18 17:30:00  618.078586

# %%
dfT2= pd.read_csv('output/Torgnon/LT_Torgnon_Shade.csv',parse_dates=[1],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfT2 = dfT2.iloc[:,1:]
dfT2.columns = ['Datetime','Tsh']
dfT2.head(10)
dfT2.Tsh.plot()
dfT.Tair.plot()

# %% [markdown]
# # Latent

# %%
df20= pd.read_csv('output/Torgnon/Torgnon_ET_Sun.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
df20 = df20.iloc[:,1:]
df20.columns = ['Datetime','TSUN']
df20.head()

df21= pd.read_csv('output/Torgnon/Torgnon_ET_Shade.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
df21 = df21.iloc[:,1:]
df21.columns = ['Datetime','TSH']
df21.head()

df22= pd.read_csv('output/Torgnon/Torgnon_Evaporation.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
df22 = df22.iloc[:,1:]
df22.columns = ['Datetime','EV']
df22.head()

df2 = pd.concat([df20,df21.iloc[:,1],df22.iloc[:,1]],axis=1)
df2['ET'] = df2['TSUN'] + df2['TSH'] + df2['EV']
# df2 = df2.iloc[:,[0,4]]
df20.TSUN.plot()
df21.TSH.plot()
df22.EV.plot()

# %%
df2.head()
# Out:
#              Datetime  TSUN  TSH        EV  ET
# 0 2013-01-01 00:00:00   NaN  NaN  0.107882 NaN
# 1 2013-01-01 00:30:00   NaN  NaN  0.107882 NaN
# 2 2013-01-01 01:00:00   NaN  NaN  0.107882 NaN
# 3 2013-01-01 01:30:00   NaN  NaN  0.107882 NaN
# 4 2013-01-01 02:00:00   NaN  NaN  0.107882 NaN

# %%
df2['ET'] = df2.TSUN.fillna(0) + df2.TSH.fillna(0) + df2.EV.fillna(0)

# %%
df2.loc[7525,:]
# Out:
# Datetime    2013-06-06 18:30:00
# TSUN                    323.547
# TSH                     91.9455
# EV                          NaN
# ET                      415.492
# Name: 7525, dtype: object

# %% [markdown]
# # Radiation

# %%
dfRadSun= pd.read_csv('output/Torgnon/RadiationCanopySun.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
dfRadSun = dfRadSun.iloc[:,1:]
dfRadSun.columns = ['Datetime','RadSun']
dfRadSun.head()

dfRad= pd.read_csv('data/Torgnon/Torgnon_SwDirect.csv',parse_dates=[1],
                 sep=',',skiprows=2,low_memory=False, na_values=(-9999,0))
dfRad = dfRad.iloc[:,1:]
dfRad.columns = ['Datetime','Rad']

dfRadSh= pd.read_csv('output/Torgnon/RadiationCanopyShade.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
dfRadSh = dfRadSh.iloc[:,1:]
dfRadSh.columns = ['Datetime','RadSh']
dfRadSh.head()
dfRad.Rad.plot()
dfRadSun.RadSun.plot()
dfRadSh.RadSh.plot()

# %%
dfLai=pd.read_csv("data/Torgnon/Torgnon_Lai.csv",parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfLai = dfLai.iloc[:,1:]
dfLai.columns = ['Datetime','Lai']
dfLai.Lai.plot()

dfLaiS=pd.read_csv("output/Torgnon/canopy.csv",parse_dates=[1],sep=',',skiprows=6,low_memory=False, na_values=-9999)
dfLaiS = dfLaiS.iloc[:,1:]
dfLaiS.columns = ['Datetime','dfLaiS']
dfLaiS.dfLaiS.plot()

# %% [markdown]
# # Sensible heat

# %%
dfHSun= pd.read_csv('output/Torgnon/HL_Torgnon_Sun.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
dfHSun = dfHSun.iloc[:,1:]
dfHSun.columns = ['Datetime','HSun']
dfHSun.HSun.plot()

dfHSh= pd.read_csv('output/Torgnon/HL_Torgnon_Shade.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
dfHSh = dfHSh.iloc[:,1:]
dfHSh.columns = ['Datetime','HSh']
dfHSh.HSh.plot()

# %%
df5= pd.read_csv('output/Viote_latentHeat_FAO_NoCal.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
df5 = df5.iloc[:,1:]
df5.columns = ['Datetime','fao']
df5.head()
# Out:
#              Datetime       fao
# 0 2005-01-01 00:00:00  8.387265
# 1 2005-01-01 00:30:00  8.387265
# 2 2005-01-01 01:00:00  8.387265
# 3 2005-01-01 01:30:00  8.387265
# 4 2005-01-01 02:00:00  8.387265

# %%
df6 = pd.read_csv('output/Viote_latentHeat_PT_NoCal.csv',parse_dates=[1],
                 sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))

# df6= pd.read_csv('output/Viote_latentHeat_PT_NoCal.csv',parse_dates=[1],
#                  sep=',',skiprows=6,low_memory=False, na_values=(-9999,0))
df6 = df6.iloc[:,1:]
df6.columns = ['Datetime','pt']
df6.head()
# Out:
#              Datetime  pt
# 0 2011-01-01 00:00:00 NaN
# 1 2011-01-01 00:30:00 NaN
# 2 2011-01-01 01:00:00 NaN
# 3 2011-01-01 01:30:00 NaN
# 4 2011-01-01 02:00:00 NaN

# %%
# print(df1.shape)
# print(df2.shape)
# print(df3.shape)
# print(df4.shape)
# print(df5.shape)
# print(df6.shape)

# %%
df = pd.concat([df1,df2.iloc[:,1],df3.iloc[:,1],df4.iloc[:,1],df5.iloc[:,1],df6.iloc[:,1]],axis=1)
print(df.shape)
df.iloc[6990:9000,:]#.head(150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-baf4e1a8d785> in <module>()
# ----> 1 df = pd.concat([df1,df2.iloc[:,1],df3.iloc[:,1],df4.iloc[:,1],df5.iloc[:,1],df6.iloc[:,1]],axis=1)
#       2 print(df.shape)
#       3 df.iloc[6990:9000,:]#.head(150)
#
# NameError: name 'df1' is not defined

# %%
df.tail()
# Out:
#                   Datetime       Obs  ET  grassland  flat       fao  pt
# 140251 2012-12-31 21:30:00  6.901803 NaN        NaN   NaN  8.387265 NaN
# 140252 2012-12-31 22:00:00       NaN NaN        NaN   NaN  8.387265 NaN
# 140253 2012-12-31 22:30:00  1.402761 NaN        NaN   NaN  8.387265 NaN
# 140254 2012-12-31 23:00:00  0.291997 NaN        NaN   NaN  8.387265 NaN
# 140255 2012-12-31 23:30:00       NaN NaN        NaN   NaN  8.387265 NaN

# %%
df.dtypes
# Out:
# Datetime     datetime64[ns]
# Obs                 float64
# ET                  float64
# grassland           float64
# flat                float64
# fao                 float64
# pt                  float64
# dtype: object

# %%
df.index =df.Datetime
df = df.iloc[:,1:]

# %%
df.iloc[:,[0,1]].plot()

# %%
# df.iloc[:,[5,0]].plot()

# %%
dfET = df

# %%
dfET = dfET.dropna()

# %%
idx = pd.date_range('2005-01-01 00:00:00','2012-12-31 23:30:00',freq='30T')
dfET.reindex(idx)

# 2005-01-01 00:00:00
#         2012-12-31 23:30:00
# Out:
#                      Obs  ET  grassland  flat  fao  pt
# 2005-01-01 00:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 00:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 01:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 01:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 02:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 02:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 03:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 03:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 04:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 04:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 05:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 05:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 06:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 06:30:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 07:00:00  NaN NaN        NaN   NaN  NaN NaN
# 2005-01-01 07:30:00  NaN NaN        NaN   NaN  NaN NaN
# ...

# %%
dfET.mean()
# Out:
# Obs          189.336459
# ET           127.168572
# grassland    103.318416
# flat         113.180924
# fao          193.455777
# pt           269.892364
# dtype: float64

# %%
dfET.describe()
# Out:
#                 Obs            ET     grassland          flat           fao  \
# count  19021.000000  19021.000000  19021.000000  19021.000000  19021.000000
# mean     189.336459    127.168572    103.318416    113.180924    193.455777
# std      106.419177     94.068603     77.695081     84.190166    109.858881
# min        0.066483      0.245981      0.020562      0.019112      2.171331
# 25%      102.309733     50.755174     39.264560     41.636837    103.130522
# 50%      180.501601    109.392571     89.211896     98.482455    182.268145
# 75%      267.963986    184.146065    152.584186    170.543593    272.297633
# max      589.488319    644.923912    486.275080    409.722107    543.154587
#
#                  pt
# count  19021.000000
# mean     269.892364
# std      156.210525
# min        0.218086
# 25%      140.674624
# 50%      256.082128
# 75%      385.547729
# max      785.492028

# %%
dfET.shape
# Out:
# (19021, 6)

# %%
dfET[['flat','Obs']].plot()

# %%
dfET[['Obs','fao']].plot()

# %%
dfDET = dfET

# %%
dfET.head()
# Out:
#                            Obs         ET  grassland      flat        fao  \
# Datetime
# 2005-05-01 06:30:00   8.227021   8.440558   0.228643  0.287309   8.825394
# 2005-05-01 07:00:00   8.353606   8.992065   0.402501  0.544420  13.032363
# 2005-05-01 07:30:00  27.914946   5.564063   2.153842  3.116844  32.364177
# 2005-05-01 08:00:00  31.828596   9.834284   3.299891  5.545457  52.584238
# 2005-05-01 08:30:00  33.509867  13.564935   5.141788  9.508639  65.182131
#
#                             pt        DET  Dgrassland
# Datetime
# 2005-05-01 06:30:00   9.708187   0.213537    7.998378
# 2005-05-01 07:00:00  16.207251   0.638459    7.951105
# 2005-05-01 07:30:00  43.892434  22.350883   25.761104
# 2005-05-01 08:00:00  69.772566  21.994312   28.528705
# 2005-05-01 08:30:00  88.896862  19.944931   28.368079

# %%
dfET['Dflat']=abs(dfET['flat']-dfET['Obs'])
dfET['Dgrassland']=abs(dfET['grassland']-dfET['Obs'])
dfET['DET']=abs(dfET['ET']-dfET['Obs'])
dfET['Dfao']=abs(dfET['fao']-dfET['Obs'])
dfET['Dpt']=abs(dfET['pt']-dfET['Obs'])
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfDET = dfET.iloc[:,6:]
dfDET.iloc[6990:7000]#.head()
# Out:
#                             DET  Dgrassland       Dflat       Dfao         Dpt
# Datetime
# 2007-09-20 08:30:00   16.263070   17.316522   17.515269   3.158902    4.279759
# 2007-09-20 09:00:00   51.486714   52.869335   52.985134  24.484516   12.743111
# 2007-09-20 09:30:00   43.329695   46.866967   46.418930  11.206506    4.619916
# 2007-09-20 10:00:00   46.962735   51.536066   50.409300  11.245161   10.399303
# 2007-09-20 10:30:00  131.774226  143.172038  130.516063  36.737014   63.240649
# 2007-09-20 11:00:00  114.055878  138.320731  109.908645  15.266607  143.595042
# 2007-09-20 11:30:00  115.904695  145.026725  106.559675  13.019214  171.007926
# 2007-09-20 12:00:00  111.024795  147.070227   98.218280  22.077423  216.154558
# 2007-09-20 12:30:00   90.696326  128.587778   79.896846  33.614677  216.112553
# 2007-09-20 13:00:00   77.713831  112.923867   70.532814  46.829405  190.082559

# %%
dfDET.mean()
# Out:
# DET           67.545432
# Dgrassland    86.858766
# Dflat         77.060465
# Dfao          28.513747
# Dpt           82.336123
# dtype: float64

# %%
a = np.linspace(-0,600,10)

# %%
import seaborn as sns

# %%
g, axes = plt.subplots(nrows=1, ncols=5, figsize=(30,5))
ax0 = axes[0] 
ax1 = axes[1]
ax2 = axes[2]
ax3 = axes[3]
ax4 = axes[4] 
 
sns.set(style="ticks")
sns.set_style("whitegrid")
g.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

##################            TORGNON            #############################
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax0,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax1,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax2,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax3,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax4,marker="o")
# g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
#                 line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax5,marker="o")
g = sns.scatterplot(x=dfET['Obs'], y=dfET['flat'],ax=ax0,palette=cmap, sizes=(5, 5))         
g = sns.scatterplot(x=dfET['Obs'], y=dfET['grassland'],ax=ax1,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['ET'],ax=ax2,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['fao'],ax=ax3,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['pt'],ax=ax4,palette=cmap, sizes=(5, 5))

# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['SWIN_N'],ax=ax3,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['CO2_N'],ax=ax4,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfLA['L_N'],ax=ax5,palette=cmap, sizes=(5, 5))

# %%
Rflat=((dfET['flat']-dfET['Obs']) ** 2).mean() ** .5
Rgrass=((dfET['grassland']-dfET['Obs']) ** 2).mean() ** .5
RmultiLayer=((dfET['ET']-dfET['Obs']) ** 2).mean() ** .5
Rfao=((dfET['fao']-dfET['Obs']) ** 2).mean() ** .5
Rpt=((dfET['pt']-dfET['Obs']) ** 2).mean() ** .5

print(Rflat)
print(Rgrass)
print(RmultiLayer)
print(Rfao)
print(Rpt)
# Out:
# 90.38680681312887
# 101.80848742908758
# 82.54969001194988
# 42.589264119706264
# 102.48099657627225

# %%
Cflat=dfET['flat'].corr(dfET['Obs'])
Cgrass=dfET['grassland'].corr(dfET['Obs']) 
CmultiLayer=dfET['ET'].corr(dfET['Obs']) 
Cfao=dfET['fao'].corr(dfET['Obs'])
Cpt=dfET['pt'].corr(dfET['Obs']) 

print(Cflat)
print(Cgrass)
print(CmultiLayer)
print(Cfao)
print(Cpt)
# Out:
# 0.8953001930968306
# 0.8705320038582571
# 0.8602883598595633
# 0.9236538558446604
# 0.9538573022902767

# %%
dfSWC= pd.read_csv('data/Viote/Viote_SWC.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
dfSWC = dfSWC.iloc[:,1:]
dfSWC.columns = ['Datetime','SWC']
# dfSWC[dfSWC['Obs']<0]=np.nan
dfSWC.head(10)
dfSWC.SWC.plot()

# %% [markdown]
# # NO PARTITION

# %%
df1= pd.read_csv('data/Torgnon/Torgnon_El_err.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
df1 = df1.iloc[:,1:]
df1.columns = ['Datetime','Obs']
df1[df1['Obs']<0]=np.nan
df1.head(10)
# Out:
#              Datetime  Obs
# 0 2013-01-01 00:00:00  NaN
# 1 2013-01-01 00:30:00  NaN
# 2 2013-01-01 01:00:00  NaN
# 3 2013-01-01 01:30:00  NaN
# 4 2013-01-01 02:00:00  NaN
# 5 2013-01-01 02:30:00  NaN
# 6 2013-01-01 03:00:00  NaN
# 7 2013-01-01 03:30:00  NaN
# 8 2013-01-01 04:00:00  NaN
# 9 2013-01-01 04:30:00  NaN

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
# Out:
# (105168, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)

# %%
df = pd.concat([df1,df2.iloc[:,1],df3.iloc[:,1],df4.iloc[:,1],df5.iloc[:,1],df6.iloc[:,1]],axis=1)
print(df.shape)
df.head()
# Out:
# (140256, 7)
#              Datetime  Obs  multiLayer  grassland       flat       fao  pt
# 0 2013-01-01 00:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 1 2013-01-01 00:30:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 2 2013-01-01 01:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 3 2013-01-01 01:30:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 4 2013-01-01 02:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN

# %%
df.tail()
# Out:
#        Datetime  Obs  multiLayer  grassland       flat       fao  pt
# 140251      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140252      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140253      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140254      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140255      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN

# %%
df.dtypes
# Out:
# Datetime      datetime64[ns]
# Obs                  float64
# multiLayer           float64
# grassland            float64
# flat                 float64
# fao                  float64
# pt                   float64
# dtype: object

# %%
df.index =df.Datetime
df = df.iloc[:,1:]

# %%
df.iloc[:,0].plot()

# %%
dfET = df.dropna()

# %%
idx = pd.date_range('2013-01-01 00:00:00','2018-12-31 23:30:00',freq='30T')
dfET.reindex(idx)

# 2005-01-01 00:00:00
#         2012-12-31 23:30:00
# Out:
#                      Obs  multiLayer  grassland  flat  fao  pt
# 2013-01-01 00:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 00:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 01:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 01:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 02:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 02:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 03:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 03:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 04:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 04:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 05:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 05:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 06:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 06:30:00  NaN         NaN        NaN   NaN  NaN NaN
# ...

# %%
dfET.mean()
# Out:
# Obs           213.729972
# multiLayer     94.130935
# grassland     145.992151
# flat          238.087100
# fao           194.666206
# pt            270.054449
# dtype: float64

# %%
dfET.describe()
# Out:
#                Obs   multiLayer    grassland         flat          fao  \
# count  9435.000000  9435.000000  9435.000000  9435.000000  9435.000000
# mean    213.729972    94.130935   145.992151   238.087100   194.666206
# std     128.359706    75.408241   110.820224   128.141934   113.268010
# min       0.145700     0.006317     0.017647     1.214465     0.843384
# 25%     110.088550    32.179101    52.817541   135.225424    99.556315
# 50%     198.405500    79.464665   127.621670   230.029564   186.548143
# 75%     305.880100   139.346621   216.989385   329.290839   278.641365
# max     617.569300   538.025546   714.198142   654.418265   521.346335
#
#                 pt
# count  9435.000000
# mean    270.054449
# std     162.189195
# min       0.101234
# 25%     134.143052
# 50%     260.897667
# 75%     394.213094
# max     785.492028

# %%
dfDET = dfET

# %%
dfET['Dflat']=abs(dfET['flat']-dfET['Obs'])
dfET['Dgrassland']=abs(dfET['grassland']-dfET['Obs'])
dfET['DmultiLayer']=abs(dfET['multiLayer']-dfET['Obs'])
dfET['Dfao']=abs(dfET['fao']-dfET['Obs'])
dfET['Dpt']=abs(dfET['pt']-dfET['Obs'])
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfDET = dfET.iloc[:,6:]
dfDET.head()
# Out:
#                           Dflat  Dgrassland  DmultiLayer        Dfao  \
# Datetime
# 2013-06-01 17:30:00  109.164516  162.025734   171.101797  139.599081
# 2013-06-01 18:00:00   87.924213  132.509296   139.355141  126.696107
# 2013-06-01 18:30:00   45.937098   91.278463    98.315154   91.002808
# 2013-06-01 19:00:00   13.434739   44.246879    55.031126   35.413423
# 2013-06-02 07:00:00   10.156133   35.625528    37.037505   22.467696
#
#                             Dpt
# Datetime
# 2013-06-01 17:30:00  129.627145
# 2013-06-01 18:00:00  133.014812
# 2013-06-01 18:30:00   95.654278
# 2013-06-01 19:00:00   30.747842
# 2013-06-02 07:00:00   22.998963

# %%
dfDET.describe()
# Out:
#              Dflat   Dgrassland  DmultiLayer         Dfao          Dpt
# count  9435.000000  9435.000000  9435.000000  9435.000000  9435.000000
# mean    114.212694   119.391299   137.619055   106.795706   136.851282
# std      88.787259    94.500649   104.559130    81.859181   103.123892
# min       0.036715     0.008975     0.000358     0.013257     0.033192
# 25%      43.880824    44.005044    51.149134    42.236010    57.275856
# 50%      95.676581    97.669144   115.374531    88.612515   117.332271
# 75%     162.041197   173.890229   203.736989   153.059520   192.288656
# max     575.623100   607.183042   542.374805   534.083481   618.637019

# %%
a = np.linspace(-0,600,10)

# %%
import seaborn as sns

# %%
g, axes = plt.subplots(nrows=1, ncols=5, figsize=(30,5))
ax0 = axes[0] 
ax1 = axes[1]
ax2 = axes[2]
ax3 = axes[3]
ax4 = axes[4] 
 
sns.set(style="ticks")
sns.set_style("whitegrid")
g.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

##################            TORGNON            #############################
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax0,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax1,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax2,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax3,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax4,marker="o")
# g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
#                 line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax5,marker="o")
g = sns.scatterplot(x=dfET['Obs'], y=dfET['flat'],ax=ax0,palette=cmap, sizes=(5, 5))         
g = sns.scatterplot(x=dfET['Obs'], y=dfET['grassland'],ax=ax1,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['multiLayer'],ax=ax2,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['fao'],ax=ax3,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['pt'],ax=ax4,palette=cmap, sizes=(5, 5))

# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['SWIN_N'],ax=ax3,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['CO2_N'],ax=ax4,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfLA['L_N'],ax=ax5,palette=cmap, sizes=(5, 5))

# %%
RoneStress=((dfET['flat']-dfET['Obs']) ** 2).mean() ** .5
RmultiStress=((dfET['grassland']-dfET['Obs']) ** 2).mean() ** .5
RmultiLayer=((dfET['multiLayer']-dfET['Obs']) ** 2).mean() ** .5
Rfao=((dfET['fao']-dfET['Obs']) ** 2).mean() ** .5
Rpt=((dfET['pt']-dfET['Obs']) ** 2).mean() ** .5

print(RoneStress)
print(RmultiStress)
print(RmultiLayer)
print(Rfao)
print(Rpt)
# Out:
# 144.66126409042764
# 152.2619734525537
# 172.8307186532632
# 134.5568217037472
# 171.3525119621825

# %%
ConeStress=dfET['flat'].corr(dfET['Obs'])
CmultiStress=dfET['grassland'].corr(dfET['Obs']) 
CmultiLayer=dfET['multiLayer'].corr(dfET['Obs']) 
Cfao=dfET['fao'].corr(dfET['Obs'])
Cpt=dfET['pt'].corr(dfET['Obs']) 

print(ConeStress)
print(CmultiStress)
print(CmultiLayer)
print(Cfao)
print(Cpt)
# Out:
# 0.3818276722032882
# 0.35712390115448567
# 0.34064368915073356
# 0.39761420836322764
# 0.3984314606628856

# %% [markdown]
# # NO ERROR

# %%
df1= pd.read_csv('data/Torgnon/Torgnon_El.csv',parse_dates=[1],sep=',',skiprows=2,low_memory=False, na_values=-9999)
df1 = df1.iloc[:,1:]
df1.columns = ['Datetime','Obs']
df1[df1['Obs']<0]=np.nan
df1.head(10)
# Out:
#              Datetime  Obs
# 0 2013-01-01 00:00:00  NaN
# 1 2013-01-01 00:30:00  NaN
# 2 2013-01-01 01:00:00  NaN
# 3 2013-01-01 01:30:00  NaN
# 4 2013-01-01 02:00:00  NaN
# 5 2013-01-01 02:30:00  NaN
# 6 2013-01-01 03:00:00  NaN
# 7 2013-01-01 03:30:00  NaN
# 8 2013-01-01 04:00:00  NaN
# 9 2013-01-01 04:30:00  NaN

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)
# Out:
# (105168, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)
# (140256, 2)

# %%
df = pd.concat([df1,df2.iloc[:,1],df3.iloc[:,1],df4.iloc[:,1],df5.iloc[:,1],df6.iloc[:,1]],axis=1)
print(df.shape)
df.head()
# Out:
# (140256, 7)
#              Datetime  Obs  multiLayer  grassland       flat       fao  pt
# 0 2013-01-01 00:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 1 2013-01-01 00:30:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 2 2013-01-01 01:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 3 2013-01-01 01:30:00  NaN         NaN        NaN  43.983269  8.387265 NaN
# 4 2013-01-01 02:00:00  NaN         NaN        NaN  43.983269  8.387265 NaN

# %%
df.tail()
# Out:
#        Datetime  Obs  multiLayer  grassland       flat       fao  pt
# 140251      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140252      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140253      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140254      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN
# 140255      NaT  NaN         NaN        NaN  43.983269  8.387265 NaN

# %%
df.dtypes
# Out:
# Datetime      datetime64[ns]
# Obs                  float64
# multiLayer           float64
# grassland            float64
# flat                 float64
# fao                  float64
# pt                   float64
# dtype: object

# %%
df.index =df.Datetime
df = df.iloc[:,1:]

# %%
df.iloc[:,0].plot()

# %%
dfET = df.dropna()

# %%
idx = pd.date_range('2013-01-01 00:00:00','2018-12-31 23:30:00',freq='30T')
dfET.reindex(idx)

# 2005-01-01 00:00:00
#         2012-12-31 23:30:00
# Out:
#                      Obs  multiLayer  grassland  flat  fao  pt
# 2013-01-01 00:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 00:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 01:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 01:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 02:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 02:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 03:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 03:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 04:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 04:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 05:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 05:30:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 06:00:00  NaN         NaN        NaN   NaN  NaN NaN
# 2013-01-01 06:30:00  NaN         NaN        NaN   NaN  NaN NaN
# ...

# %%
dfET.describe()
# Out:
#                Obs   multiLayer    grassland         flat          fao  \
# count  9593.000000  9593.000000  9593.000000  9593.000000  9593.000000
# mean    198.214884    93.046796   144.309543   235.864460   192.633093
# std     140.607234    75.354574   110.823138   128.488176   113.589195
# min       0.075200     0.006317     0.017647     1.214465     0.843384
# 25%      76.711100    31.079427    50.951260   132.184019    96.708062
# 50%     176.345000    77.740759   125.180401   227.038792   184.318973
# 75%     302.395300   138.358197   215.500733   327.836541   277.107237
# max     597.821900   538.025546   714.198142   654.418265   521.346335
#
#                 pt
# count  9593.000000
# mean    267.101828
# std     162.676004
# min       0.101234
# 25%     129.910146
# 50%     257.467858
# 75%     391.387351
# max     785.492028

# %%
dfDET = dfET

# %%
dfET['Dflat']=abs(dfET['flat']-dfET['Obs'])
dfET['Dgrassland']=abs(dfET['grassland']-dfET['Obs'])
dfET['DmultiLayer']=abs(dfET['multiLayer']-dfET['Obs'])
dfET['Dfao']=abs(dfET['fao']-dfET['Obs'])
dfET['Dpt']=abs(dfET['pt']-dfET['Obs'])
# Out:
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/drugo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfDET = dfET.iloc[:,6:]
dfDET.head()
# Out:
#                          Dflat  Dgrassland  DmultiLayer       Dfao        Dpt
# Datetime
# 2013-06-01 17:30:00   4.803584   48.057634    57.133697  25.630981  15.659045
# 2013-06-01 18:00:00   0.116387   44.468696    51.314541  38.655507  44.974212
# 2013-06-01 18:30:00  18.880902   26.460463    33.497154  26.184808  30.836278
# 2013-06-01 19:00:00  76.707139   19.025521     8.241274  27.858977  32.524558
# 2013-06-02 07:00:00  22.851967    2.617428     4.029405  10.540404  10.009137

# %%
dfDET.mean()
# Out:
# Dflat          122.963361
# Dgrassland     120.209339
# DmultiLayer    132.591046
# Dfao           112.804376
# Dpt            143.681955
# dtype: float64

# %%
a = np.linspace(-0,600,10)

# %%
import seaborn as sns

# %%
g, axes = plt.subplots(nrows=1, ncols=5, figsize=(30,5))
ax0 = axes[0] 
ax1 = axes[1]
ax2 = axes[2]
ax3 = axes[3]
ax4 = axes[4] 
 
sns.set(style="ticks")
sns.set_style("whitegrid")
g.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

##################            TORGNON            #############################
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax0,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax1,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax2,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax3,marker="o")
g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
                line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax4,marker="o")
# g = sns.regplot(x=a, y=a, ci = False,scatter_kws={"color":"black","alpha":0.3,"s":0},
#                 line_kws={"color":"k","alpha":1.0,"lw":4},ax=ax5,marker="o")
g = sns.scatterplot(x=dfET['Obs'], y=dfET['flat'],ax=ax0,palette=cmap, sizes=(5, 5))         
g = sns.scatterplot(x=dfET['Obs'], y=dfET['grassland'],ax=ax1,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['multiLayer'],ax=ax2,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['fao'],ax=ax3,palette=cmap, sizes=(5, 5))
g = sns.scatterplot(x=dfET['Obs'], y=dfET['pt'],ax=ax4,palette=cmap, sizes=(5, 5))

# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['SWIN_N'],ax=ax3,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfAA['CO2_N'],ax=ax4,palette=cmap, sizes=(5, 5))
# g = sns.scatterplot(x=dfAA['LHF_N'], y=dfLA['L_N'],ax=ax5,palette=cmap, sizes=(5, 5))

# %%
RoneStress=((dfET['flat']-dfET['Obs']) ** 2).mean() ** .5
RmultiStress=((dfET['grassland']-dfET['Obs']) ** 2).mean() ** .5
RmultiLayer=((dfET['multiLayer']-dfET['Obs']) ** 2).mean() ** .5
Rfao=((dfET['fao']-dfET['Obs']) ** 2).mean() ** .5
Rpt=((dfET['pt']-dfET['Obs']) ** 2).mean() ** .5

print(RoneStress)
print(RmultiStress)
print(RmultiLayer)
print(Rfao)
print(Rpt)
# Out:
# 155.4583624983816
# 155.87720493573107
# 172.45335408348694
# 141.91010563494524
# 181.43297963711862

# %%
ConeStress=dfET['flat'].corr(dfET['Obs'])
CmultiStress=dfET['grassland'].corr(dfET['Obs']) 
CmultiLayer=dfET['multiLayer'].corr(dfET['Obs']) 
Cfao=dfET['fao'].corr(dfET['Obs'])
Cpt=dfET['pt'].corr(dfET['Obs']) 

print(ConeStress)
print(CmultiStress)
print(CmultiLayer)
print(Cfao)
print(Cpt)
# Out:
# 0.3743813545994493
# 0.34198590494281034
# 0.3193332574779418
# 0.39331030333449823
# 0.39474687435307415
